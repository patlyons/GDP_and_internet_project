# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv', skiprows = [6870, 6871, 6872, 6873])

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2019  2065.036398              NaN
# 1        Afghanistan  2018  2033.779002              NaN
# 2        Afghanistan  2017  2058.383832              NaN
# 3        Afghanistan  2016  2057.062164              NaN
# 4        Afghanistan  2015  2068.265904              NaN
# ...              ...   ...          ...              ...
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN
#
# [6868 rows x 4 columns]

# %%
gdp_df.drop('Value Footnotes', axis =1, inplace = True)

# %%
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2019  2065.036398
# 1        Afghanistan  2018  2033.779002
# 2        Afghanistan  2017  2058.383832
# 3        Afghanistan  2016  2057.062164
# 4        Afghanistan  2015  2068.265904
# ...              ...   ...          ...
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171
#
# [6868 rows x 3 columns]

# %%
internet_df = pd.read_csv('../data/internet_use.csv', skiprows = [i for i in range(4497, 4688)])

# %%
internet_df
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
#
# [4495 rows x 4 columns]

# %%
internet_df.drop('Value Footnotes', axis =1, inplace = True)

# %%
internet_df
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value
# 4485        Zimbabwe  2002  3.994356
# 4486        Zimbabwe  2001  0.799846
# 4487        Zimbabwe  2000  0.401434
# 4488        Zimbabwe  1999  0.161676
# 4489        Zimbabwe  1998  0.081648
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value
# 6858        Zimbabwe  1999  3600.849291
# 6859        Zimbabwe  1998  3653.920016
# 6860        Zimbabwe  1997  3580.048793
# 6861        Zimbabwe  1996  3520.430146
# 6862        Zimbabwe  1995  3226.413930
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171

# %%
gdp_df.rename({'Country or Area':'Country','Year':'Year','Value':'GDP_Per_Capita'}, axis =1, inplace = True)

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
internet_df.rename({'Country or Area':'Country', 'Year':'Year', 'Value':'Internet_Users_Pct'}, axis = 1, inplace = True)

# %%
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %%
gdp_and_internet_use = gdp_df.merge(internet_df, on=['Country', 'Year'], how='outer')

# %%
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2019     2065.036398                 NaN
# 1     Afghanistan  2018     2033.779002                 NaN
# 2     Afghanistan  2017     2058.383832                 NaN
# 3     Afghanistan  2016     2057.062164                 NaN
# 4     Afghanistan  2015     2068.265904                 NaN
# ...           ...   ...             ...                 ...
# 7900        Yemen  1999             NaN            0.056629
# 7901        Yemen  1998             NaN            0.023323
# 7902        Yemen  1997             NaN            0.015025
# 7903        Yemen  1996             NaN            0.000621
# 7904        Yemen  1990             NaN            0.000000
#
# [7905 rows x 4 columns]

# %%
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2019     2065.036398                 NaN
# 1  Afghanistan  2018     2033.779002                 NaN
# 2  Afghanistan  2017     2058.383832                 NaN
# 3  Afghanistan  2016     2057.062164                 NaN
# 4  Afghanistan  2015     2068.265904                 NaN

# %%
gdp_and_internet_use.tail(10)
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7895   Yemen  2004             NaN            0.881223
# 7896   Yemen  2003             NaN            0.604734
# 7897   Yemen  2002             NaN            0.518796
# 7898   Yemen  2001             NaN            0.090802
# 7899   Yemen  2000             NaN            0.082500
# 7900   Yemen  1999             NaN            0.056629
# 7901   Yemen  1998             NaN            0.023323
# 7902   Yemen  1997             NaN            0.015025
# 7903   Yemen  1996             NaN            0.000621
# 7904   Yemen  1990             NaN            0.000000

# %%
gdp_and_internet_use[gdp_and_internet_use["Year"] == 2004]
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15              Afghanistan  2004     1200.278256            0.105809
# 33                  Albania  2004     7604.838002            2.420388
# 63                  Algeria  2004    10058.435939            4.634475
# 93                   Angola  2004     5593.241537            0.464815
# 123     Antigua and Barbuda  2004    18745.681534           24.266544
# ...                     ...   ...             ...                 ...
# 7771     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7829              Venezuela  2004             NaN            8.404470
# 7853               Viet Nam  2004             NaN            7.642409
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7895                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
y2k4 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2004]

# %%
y2k4
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15              Afghanistan  2004     1200.278256            0.105809
# 33                  Albania  2004     7604.838002            2.420388
# 63                  Algeria  2004    10058.435939            4.634475
# 93                   Angola  2004     5593.241537            0.464815
# 123     Antigua and Barbuda  2004    18745.681534           24.266544
# ...                     ...   ...             ...                 ...
# 7771     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7829              Venezuela  2004             NaN            8.404470
# 7853               Viet Nam  2004             NaN            7.642409
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7895                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
y2k4.sort_values(by = 'GDP_Per_Capita', ascending = False).head(5)
# Out:
#                    Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3701            Luxembourg  2004   102708.212547           65.880000
# 6527  United Arab Emirates  2004    97758.023345           30.131296
# 5148                 Qatar  2004    93748.301216           20.701648
# 571                Bermuda  2004    90195.811033           60.990867
# 5306            San Marino  2004    80391.828516           50.566343

# %%
y2k4.sort_values(by = 'Internet_Users_Pct', ascending = True).head(5)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7088  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 4342                      Myanmar  2004     1696.881760            0.024337
# 3545                      Liberia  2004     1181.546158            0.031011
# 6079                   Tajikistan  2004     1737.743630            0.077480
# 15                    Afghanistan  2004     1200.278256            0.105809

# %%
y2k4.sort_values(by = 'Internet_Users_Pct', ascending = False).head(5)
# Out:
#               Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6019           Sweden  2004    44496.023401               83.89
# 2635          Iceland  2004    45145.545658               83.88
# 1462          Denmark  2004    50607.628971               80.93
# 4658           Norway  2004    60893.410993               77.69
# 7400  Korea (Rep. of)  2004             NaN               72.70

# %%
y2k9 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2009]

# %%
y2k14 = gdp_and_internet_use[gdp_and_internet_use["Year"] == 2014]

# %%
y2k14.sort_values(by = 'Internet_Users_Pct', ascending = False).head(5)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2625  Iceland  2014    49652.149500               98.16
# 561   Bermuda  2014    77361.104881               96.80
# 4648   Norway  2014    62589.373548               96.30
# 1452  Denmark  2014    52214.537753               95.99
# 6871  Andorra  2014             NaN               95.90

# %%
y2k14.sort_values(by = 'Internet_Users_Pct', ascending = True).head(5)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7079  Dem. People's Rep. of Korea  2014             NaN                0.00
# 7137                      Eritrea  2014             NaN                0.99
# 6219                  Timor-Leste  2014     3264.568070                1.14
# 827                       Burundi  2014      886.235777                1.38
# 7674                      Somalia  2014             NaN                1.63

# %%
y2k9.sort_values(by = 'Internet_Users_Pct', ascending = False).head(5)
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2630      Iceland  2009    48177.084123               93.00
# 4653       Norway  2009    61886.564498               92.08
# 6014       Sweden  2009    45638.035577               91.00
# 4443  Netherlands  2009    51772.424928               89.63
# 3696   Luxembourg  2009   104932.811953               87.31

# %%
y2k9.sort_values(by ='Internet_Users_Pct', ascending = True).head(5)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7083  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 6224                  Timor-Leste  2009     2724.770973            0.185252
# 4337                      Myanmar  2009     2874.780227            0.220000
# 5439                 Sierra Leone  2009     1372.392285            0.260000
# 922                      Cambodia  2009     2603.583778            0.530000

# %%
plt.plot(y2k4.Internet_Users_Pct, y2k4.GDP_Per_Capita, 'x', color = 'red')
plt.xlabel('Internet Use')
plt.ylabel('GDP')
# Out:
# Text(0, 0.5, 'GDP')

# %%
plt.plot(y2k9.Internet_Users_Pct, y2k9.GDP_Per_Capita, 'x', color = 'green')
plt.xlabel('Internet Use')
plt.ylabel('GDP')
# Out:
# Text(0, 0.5, 'GDP')

# %%
plt.scatter(y2k14.Internet_Users_Pct, y2k14.GDP_Per_Capita, alpha = 0.5)
plt.xlabel('Internet Use')
plt.ylabel('GDP');

# %%
# The scatter plot become more like a line over the years

# %%
# no years have unimodal data

# %%
# Iceland Norway sweeden denmark Luxembourg

# %%
sns.distplot(y2k14.GDP_Per_Capita, bins = 15)
# Out:
# /Users/patricklyons/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GDP_Per_Capita', ylabel='Density'>

# %%
sns.distplot(y2k14.Internet_Users_Pct, bins = 15, color = 'orange')
# Out:
# <AxesSubplot:xlabel='Internet_Users_Pct', ylabel='Density'>

# %%
concat_data = pd.concat([y2k4.head(5), y2k9.head(5), y2k14.head(5)])
concat_data
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15           Afghanistan  2004     1200.278256            0.105809
# 33               Albania  2004     7604.838002            2.420388
# 63               Algeria  2004    10058.435939            4.634475
# 93                Angola  2004     5593.241537            0.464815
# 123  Antigua and Barbuda  2004    18745.681534           24.266544
# 10           Afghanistan  2009     1758.904043            3.550000
# 28               Albania  2009    10346.864199           41.200000
# 58               Algeria  2009    10782.361398           11.230000
# 88                Angola  2009     7643.493749            6.000000
# 118  Antigua and Barbuda  2009    20046.839017           42.000000
# 5            Afghanistan  2014     2102.385234            6.390000
# 23               Albania  2014    11623.866679           60.100000
# 53               Algeria  2014    11512.705405           18.090000
# 83                Angola  2014     8239.828837           21.260000
# 113  Antigua and Barbuda  2014    18104.241470           64.000000

# %%
y2k14_Int = y2k14.sort_values(by = 'Internet_Users_Pct', ascending = False).head(5)
y2k14_Int
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2625  Iceland  2014    49652.149500               98.16
# 561   Bermuda  2014    77361.104881               96.80
# 4648   Norway  2014    62589.373548               96.30
# 1452  Denmark  2014    52214.537753               95.99
# 6871  Andorra  2014             NaN               95.90

# %%
y2k14_countries = y2k14_Int['Country']

# %%
y2k9_Int = y2k9.loc[y2k9['Country'].isin(y2k14_countries)]

# %%
y2k9_Int
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 566   Bermuda  2009    89961.982744               83.25
# 1457  Denmark  2009    50274.075696               86.84
# 2630  Iceland  2009    48177.084123               93.00
# 4653   Norway  2009    61886.564498               92.08
# 6876  Andorra  2009             NaN               78.53

# %%
y2k4_Int = y2k4.loc[y2k4['Country'].isin(y2k14_countries)]

# %%
y2k4_Int
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 571   Bermuda  2004    90195.811033           60.990867
# 1462  Denmark  2004    50607.628971           80.930000
# 2635  Iceland  2004    45145.545658           83.880000
# 4658   Norway  2004    60893.410993           77.690000
# 6881  Andorra  2004             NaN           26.837954

# %%
top_5_internet = pd.concat([y2k4_Int, y2k9_Int, y2k14_Int])
top_5_internet
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 571   Bermuda  2004    90195.811033           60.990867
# 1462  Denmark  2004    50607.628971           80.930000
# 2635  Iceland  2004    45145.545658           83.880000
# 4658   Norway  2004    60893.410993           77.690000
# 6881  Andorra  2004             NaN           26.837954
# 566   Bermuda  2009    89961.982744           83.250000
# 1457  Denmark  2009    50274.075696           86.840000
# 2630  Iceland  2009    48177.084123           93.000000
# 4653   Norway  2009    61886.564498           92.080000
# 6876  Andorra  2009             NaN           78.530000
# 2625  Iceland  2014    49652.149500           98.160000
# 561   Bermuda  2014    77361.104881           96.800000
# 4648   Norway  2014    62589.373548           96.300000
# 1452  Denmark  2014    52214.537753           95.990000
# 6871  Andorra  2014             NaN           95.900000

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
g = sb.FacetGrid(df, col = "sex", hue = "smoker")
g.map(plt.scatter, "total_bill", "tip")
plt.show()
